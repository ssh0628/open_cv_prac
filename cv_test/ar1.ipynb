# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img1 = cv.imread("./data/ml.png")
img2 = cv.imread("./data/opencv-logo.png")

# %%
img1 = cv.resize(img1, (600, 794), 0, 0, cv.INTER_LINEAR)
print(img1.shape)
print(img2.shape)
# Out:
# (794, 600, 3)
# (794, 600, 3)

# %%
dst = cv.addWeighted(img1,0.7,img2,0.3,0)

# %%
plt.imshow(dst)

# %%
img1 = cv.imread("./data/messi5.jpg")
img2 = cv.imread("./data/opencv-logo-white.png")

# %%
img2gray = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)
ret, mask = cv.threshold(img2gray, 10, 255, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)

# %%
img2_fg = cv.bitwise_and(img2, img2, mask=mask)
plt.imshow(cv.cvtColor(img2_fg, cv.COLOR_BGR2RGB))

# %%
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols]

# %%
img1_bg = cv.bitwise_and(roi,roi,mask = mask_inv)
plt.imshow(cv.cvtColor(img1_bg, cv.COLOR_BGR2RGB))

# %%
dst = cv.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst

# %%
plt.imshow(cv.cvtColor(img1, cv.COLOR_BGR2RGB))

# %%
import os
folder = "data"
file_list = os.listdir(folder)
playlist = []
for file in file_list:
    if file.endswith('.jpg') or file.endswith('png'):
        playlist.append(file)
print(playlist)
# Out:
# ['fruits.jpg', 'aloeR.jpg', 'lena.jpg', 'starry_night.jpg', 'right09.jpg', 'sudoku.png', 'left05.jpg', 'LinuxLogo.jpg', 'right02.jpg', 'stuff.jpg', 'ela_original.jpg', 'left03.jpg', 'pic4.png', 'left06.jpg', 'rubberwhale1.png', 'left09.jpg', 'pic3.png', 'butterfly.jpg', 'blox.jpg', 'digits.png', 'apple.jpg', 'left.jpg', 'right11.jpg', 'building.jpg', 'left07.jpg', 'right14.jpg', 'box_in_scene.png', 'right.jpg', 'right06.jpg', 'Blender_Suzanne2.jpg', 'leuvenA.jpg', 'imageTextR.png', 'left12.jpg', 'left02.jpg', 'box.png', 'leuvenB.jpg', 'WindowsLogo.jpg', 'right08.jpg', 'ela_modified.jpg', 'baboon.jpg', 'left01.jpg', 'squirrel_cls.jpg', 'aero3.jpg', 'pic1.png', 'right07.jpg', 'graf1.png', 'right04.jpg', 'pca_test1.jpg', 'left13.jpg', 'ml.png', 'gradient.png', 'rubberwhale2.png', 'board.jpg', 'detect_blob.png', 'home.jpg', 'aero1.jpg', 'aloeGT.png', 'right12.jpg', 'text_motion.jpg', 'left14.jpg', 'opencv-logo.png', 'pic2.png', 'ellipses.jpg', 'basketball2.png', 'pic6.png', 'imageTextN.p
# ...

# %%
i = 0
for file in playlist:
    file = cv.resize(playlist[i], (600, 794), 0, 0, cv.INTER_LINEAR)
    dst = cv.addWeighted(img1,0.7,img2,0.3,0)
