# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('cat.png')
# img[:, :, 1] = 0
# img = cv.add(img, 100)

# %%
plt.imshow(img)

# %%
img1 = np.zeros((255,255,3))

# %%
plt.imshow(img1)

# %%
img1 = np.full((255, 255, 3), (100, 200, 160))
img2 = np.random.randint(0, 255, (255, 255, 3))

# %%
plt.imshow(img1)

# %%
def cal(x):
    result = (x**2) + (2*x) + 1
    return result

# %%
cal(10)
# Out:
# 121

# %%
def makesomenoise(x, y):
    img = np.random.randint(0, 255, (x, y, 3))
    return img

# %%
img = makesomenoise(100, 100)
plt.imshow(img)
