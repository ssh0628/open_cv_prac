# %%
import numpy as np
import cv2 as cv

# %%
img = cv.imread('./data/messi5.jpg')
assert img is not None

# %%
import matplotlib.pyplot as plt
# plt.imshow(img[:,:,::-1])
# plt.imshow(cv.cvtColor(img,cv.COLOR_BGR2GRAY))

# %%
img[100:200, 100, 2]
# Out:
# array([200, 199, 195, 194, 190, 172,  86,  36,  33,  25,  14,  18,  11,
#         12,  15,  12,  12,  15,  12,  10,  14,  12,  10,  10,   9,   9,
#          9,   8,  10,  11,  12,  14,  18,  21,  25,  30,  39,  47,  54,
#         62,  70,  79,  84,  91,  97,  98,  98,  96,  94,  91,  87,  83,
#         77,  70,  63,  53,  42,  33,  25,  20,  17,  17,  19,  20,  20,
#         23,  23,  29,  34,  39,  41,  39,  42,  45,  49,  50,  54,  58,
#         60,  67,  69,  71,  76,  77,  77,  81,  82,  81,  80,  77,  76,
#         74,  75,  76,  80,  81,  84,  89,  93,  98], dtype=uint8)

# %%
ball = img[280:340, 330:390]
img[273:333, 100:160] = ball
plt.imshow(img[:,:,::-1])

# %%
img = cv.imread('./data/messi5.jpg')
img = img[:,:,::-1]
assert img is not None

# %%
img = cv.add(img, 100)

# %%
plt.imshow(img)
